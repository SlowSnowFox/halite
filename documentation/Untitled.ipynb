# %%
import networkx as nx
import matplotlib
import pickle
import pygraphviz as pg
# %matplotlib inline
from matplotlib.pyplot import figure

# %%
net = pickle.load(open("exp.p", "rb"))

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
nx.draw(net)
# Out:
# /home/norm/miniconda3/envs/mlenv/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
nx.draw(net.subgraph(['002, 1', '003, 1']))
# Out:
# /home/norm/miniconda3/envs/mlenv/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
